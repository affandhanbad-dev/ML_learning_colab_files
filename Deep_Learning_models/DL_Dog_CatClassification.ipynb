# %% [markdown]
# <a href="https://colab.research.google.com/github/affandhanbad-dev/ML_learning_colab_files/blob/main/DL_Dog_CatClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
# !rm -rf /content/*

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory

# %%
import zipfile

# %%
# !kaggle competitions download -c dogs-vs-cats
# Out:
# ...
#  95% 775M/812M [00:07<00:00, 39.5MB/s]
# 100% 812M/812M [00:07<00:00, 119MB/s]

# %%
with zipfile.ZipFile('dogs-vs-cats.zip', 'r') as zip_ref:
    zip_ref.extractall()

# %%
with zipfile.ZipFile('train.zip', 'r') as zip_ref:
    zip_ref.extractall()

# %%
import os
path, dirs , files = next(os.walk("train"))
file_count = len(files)
print(file_count)
# Out:
# 25000

# %%
file_name = os.listdir('train')
print(file_name)
# Out:
# ['cat.211.jpg', 'cat.12334.jpg', 'dog.7392.jpg', 'cat.10643.jpg', 'cat.1316.jpg', 'dog.5086.jpg', 'cat.1173.jpg', 'cat.2484.jpg', 'dog.9462.jpg', 'cat.12259.jpg', 'cat.552.jpg', 'cat.8999.jpg', 'dog.2266.jpg', 'cat.5400.jpg', 'dog.4101.jpg', 'cat.4281.jpg', 'cat.2210.jpg', 'cat.6891.jpg', 'dog.5121.jpg', 'dog.4924.jpg', 'dog.5589.jpg', 'dog.10124.jpg', 'cat.9025.jpg', 'dog.754.jpg', 'dog.4483.jpg', 'dog.10875.jpg', 'dog.4474.jpg', 'cat.8665.jpg', 'cat.11083.jpg', 'cat.8221.jpg', 'cat.2422.jpg', 'cat.6101.jpg', 'cat.6262.jpg', 'dog.8446.jpg', 'cat.2249.jpg', 'dog.5147.jpg', 'dog.2229.jpg', 'dog.6006.jpg', 'cat.6209.jpg', 'dog.10137.jpg', 'dog.4592.jpg', 'cat.9710.jpg', 'dog.7189.jpg', 'dog.5539.jpg', 'dog.9170.jpg', 'dog.4903.jpg', 'dog.2016.jpg', 'dog.2116.jpg', 'dog.8835.jpg', 'dog.1116.jpg', 'cat.1199.jpg', 'dog.10382.jpg', 'cat.11136.jpg', 'dog.5083.jpg', 'cat.11679.jpg', 'dog.9640.jpg', 'cat.9809.jpg', 'dog.7440.jpg', 'cat.284.jpg', 'cat.9782.jpg', 'dog.3100.jpg', 'dog.10719.jpg'
# ...

# %%
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
from google.colab.patches import cv2_imshow
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split

# %%
img = mpimg.imread('/content/train/dog.8298.jpg')
plt.imshow(img)
plt.axis('off')
# plt.show()
# Out:
# (np.float64(-0.5), np.float64(498.5), np.float64(374.5), np.float64(-0.5))

# %%
img = mpimg.imread('/content/train/cat.10559.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(499.5), np.float64(373.5), np.float64(-0.5))

# %%
file_name = os.listdir('train')
dog = 0
cat = 0
for name in file_name:
  if name.startswith('dog'):
    dog += 1
  elif name.startswith('cat'):
    cat += 1
print(dog)
print(cat)
# Out:
# 12500
# 12500

# %%
os.mkdir('/content/resize')

# %%
original_path = '/content/train/'
resized_path = '/content/resize/'

for i in range(2500):
 file_name = os.listdir('train')
 path = original_path+file_name[i]
 img = Image.open(path)
 img = img.resize((224,224))
 img = img.convert('RGB')
 img.save(resized_path+file_name[i])

# %%
 file_name = os.listdir('resize')
 print(file_name)
# Out:
# ['cat.211.jpg', 'cat.12334.jpg', 'dog.7392.jpg', 'cat.10643.jpg', 'cat.1316.jpg', 'dog.5086.jpg', 'cat.1173.jpg', 'cat.2484.jpg', 'dog.9462.jpg', 'cat.12259.jpg', 'cat.552.jpg', 'cat.8999.jpg', 'dog.2266.jpg', 'cat.5400.jpg', 'dog.4101.jpg', 'cat.4281.jpg', 'cat.2210.jpg', 'cat.6891.jpg', 'dog.5121.jpg', 'dog.4924.jpg', 'dog.5589.jpg', 'dog.10124.jpg', 'cat.9025.jpg', 'dog.754.jpg', 'dog.4483.jpg', 'dog.10875.jpg', 'dog.4474.jpg', 'cat.8665.jpg', 'cat.11083.jpg', 'cat.8221.jpg', 'cat.2422.jpg', 'cat.6101.jpg', 'cat.6262.jpg', 'dog.8446.jpg', 'cat.2249.jpg', 'dog.5147.jpg', 'dog.2229.jpg', 'dog.6006.jpg', 'cat.6209.jpg', 'dog.10137.jpg', 'dog.4592.jpg', 'cat.9710.jpg', 'dog.7189.jpg', 'dog.5539.jpg', 'dog.9170.jpg', 'dog.4903.jpg', 'dog.2016.jpg', 'dog.2116.jpg', 'dog.8835.jpg', 'dog.1116.jpg', 'cat.1199.jpg', 'dog.10382.jpg', 'cat.11136.jpg', 'dog.5083.jpg', 'cat.11679.jpg', 'dog.9640.jpg', 'cat.9809.jpg', 'dog.7440.jpg', 'cat.284.jpg', 'cat.9782.jpg', 'dog.3100.jpg', 'dog.10719.jpg'
# ...

# %%
img = mpimg.imread('/content/resize/dog.7392.jpg')
plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(223.5), np.float64(223.5), np.float64(-0.5))

# %%
file_name = os.listdir('resize')
dog = 0
cat = 0
for name in file_name:
  if name.startswith('dog'):
    dog += 1
  elif name.startswith('cat'):
    cat += 1
print(dog)
print(cat)
# Out:
# 1242
# 1258

# %%
file_name = os.listdir('resize')
label = []
for i in range(2500):
  if file_name[i].startswith('dog'):
    label.append(1)
  elif file_name[i].startswith('cat'):
    label.append(0)

# %%
print(file_name[0:5])
print(len(file_name))
print(label[0:5])
print(len(label))
# Out:
# ['cat.211.jpg', 'cat.12334.jpg', 'dog.7392.jpg', 'cat.10643.jpg', 'cat.1316.jpg']
# 2500
# [0, 0, 1, 0, 0]
# 2500

# %%
import cv2
import glob

# %%
img_dir = '/content/resize/'
img_extension = ['png','jpg']
files = []
[files.extend(glob.glob(img_dir+"*." +e))for e in img_extension]
dog_cat_img = np.asarray([cv2.imread(file) for file in files])

# %%
file_name = os.listdir('resize')
dog = 0
cat = 0
for name in file_name:
  if name.startswith('dog'):
    dog += 1
  elif name.startswith('cat'):
    cat += 1
print(dog)
print(cat)
# Out:
# 1242
# 1258

# %%
len(dog_cat_img)
# Out:
# 2500

# %%
dog_cat_img.shape
# Out:
# (2500, 224, 224, 3)

# %%
X = dog_cat_img
Y = np.asarray(label)

# %%
file_name = os.listdir('resize')
dog = 0
cat = 0
for name in file_name:
  if name.startswith('dog'):
    dog += 1
  elif name.startswith('cat'):
    cat += 1
print(dog)
print(cat)
# Out:
# 1242
# 1258

# %%
X.shape,Y.shape
# Out:
# ((2500, 224, 224, 3), (2500,))

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
X_train.shape , X_test.shape
# Out:
# ((2000, 224, 224, 3), (500, 224, 224, 3))

# %%
X_train_reshape = X_train/255
X_test_reshape = X_test/255

# %%
file_name = os.listdir('resize')
dog = 0
cat = 0
for name in file_name:
  if name.startswith('dog'):
    dog += 1
  elif name.startswith('cat'):
    cat += 1
print(dog)
print(cat)
# Out:
# 1242
# 1258

# %%
X_train_reshape
# Out:
# array([[[[0.44705882, 0.56470588, 0.67058824],
#          [0.43921569, 0.55686275, 0.6627451 ],
#          [0.43529412, 0.55294118, 0.65882353],
#          ...,
#          [0.40784314, 0.54901961, 0.58823529],
#          [0.40392157, 0.55686275, 0.59215686],
#          [0.40784314, 0.56078431, 0.59607843]],
#
#         [[0.45490196, 0.57254902, 0.67843137],
#          [0.44705882, 0.56470588, 0.67058824],
#          [0.44313725, 0.56078431, 0.66666667],
#          ...,
#          [0.4       , 0.54117647, 0.58039216],
#          [0.39607843, 0.54901961, 0.58431373],
#          [0.4       , 0.55294118, 0.58823529]],
#
#         [[0.46666667, 0.58431373, 0.69019608],
#          [0.45882353, 0.57647059, 0.68235294],
#          [0.45490196, 0.57254902, 0.67843137],
#          ...,
#          [0.39215686, 0.53333333, 0.57254902],
#          [0.38823529, 0.54117647, 0.57647059],
#          [0.39215686, 0.54509804, 0.58039216]],
#
#         ...,
#
# ...

# %%
import tensorflow as tf
import tensorflow_hub as hub
# from tensorflow import keras

# %%
model = tf.keras.applications.MobileNetV2(
    input_shape=(224, 224, 3),
    weights='imagenet'
)

# %%
num_of_classes = 2

model = tf.keras.Sequential([

    model,
    tf.keras.layers.Dense(num_of_classes)

])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224            │ (None, 1000)           │     3,538,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 2)              │         2,002 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,540,986 (13.51 MB)
#  Trainable params: 3,506,874 (13.38 MB)
#  Non-trainable params: 34,112 (133.25 KB)

# %%
model.compile(
    optimizer = 'adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics = ['acc']
)

# %%
file_name = os.listdir('resize')
dog = 0
cat = 0
for name in file_name:
  if name.startswith('dog'):
    dog += 1
  elif name.startswith('cat'):
    cat += 1
print(dog)
print(cat)
# Out:
# 1242
# 1258

# %%
model.fit(X_train_reshape, Y_train, epochs=5)
# Out:
# Epoch 1/5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 104s 641ms/step - acc: 0.8546 - loss: 0.6455
# Epoch 2/5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 103ms/step - acc: 0.8738 - loss: 0.5948
# Epoch 3/5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 106ms/step - acc: 0.8459 - loss: 0.5770
# Epoch 4/5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 104ms/step - acc: 0.8033 - loss: 0.5750
# Epoch 5/5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 107ms/step - acc: 0.7827 - loss: 0.5661

# %%
loss, accuracy = model.evaluate(X_test_reshape, Y_test)
print('Test accuracy :', accuracy)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 15s 729ms/step - acc: 0.4882 - loss: 0.7525
# Test accuracy : 0.5040000081062317

# %%
import pickle
with open('Dog_cat_classification.pkl', 'wb') as file:
    pickle.dump(model, file)

# %%
input_image_path = input('Path of the image to be predicted: ')

input_image = cv2.imread(input_image_path)

cv2_imshow(input_image)

input_image_resize = cv2.resize(input_image, (224,224))

input_image_scaled = input_image_resize/255

image_reshaped = np.reshape(input_image_scaled, [1,224,224,3])

input_prediction = model.predict(image_reshaped)

print(input_prediction)

input_pred_label = np.argmax(input_prediction)

print(input_pred_label)

if input_pred_label == 0:
  print('The image represents a Cat')

else:
  print('The image represents a Dog')
# Out:
# Path of the image to be predicted:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2315590029.py in <cell line: 0>()
#       3 input_image = cv2.imread(input_image_path)
#       4
# ----> 5 cv2_imshow(input_image)
#       6
#       7 input_image_resize = cv2.resize(input_image, (224,224))
#
# /usr/local/lib/python3.12/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      16       (N, M, 4) is an NxM BGRA color image.
#      17   """
# ---> 18   a = a.clip(0, 255).astype('uint8')
#      19   # cv2 stores colors as BGR; convert to RGB
#      20   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'
